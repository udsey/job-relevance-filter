# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# 2026-05-05 16:36:00,060 [ERROR] autoreload - Failed to reload module 'scr.setup' from file '/home/lapa/Projects/job-relevance-filter/scr/setup.py'
# Traceback (most recent call last):
#   File "/home/lapa/Projects/job-relevance-filter/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/lapa/Projects/job-relevance-filter/.venv/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 584, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/home/lapa/.local/share/uv/python/cpython-3.11.12-linux-x86_64-gnu/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ...

# %%
from scr.scraper import find_new_jobs

# %%
find_new_jobs()
# Out:
# 2026-05-05 16:17:35,410 [INFO] scr.scraper - Found 10 jobs!
# Adding job details : 100%|██████████| 10/10 [00:25<00:00,  2.51s/it]
# 2026-05-05 16:18:00,512 [INFO] scr.scraper - Done! Saved 10 new jobs into /home/lapa/Projects/job-relevance-filter/data/jobs.csv
